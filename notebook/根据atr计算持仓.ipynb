# %%
all_instruments(type="Future")
# Out:
#      abbrev_symbol  contract_multiplier de_listed_date exchange listed_date  \
# 0             null                 10.0     2018-09-14      DCE  2017-09-15
# 1          PTA1210                  5.0     2012-10-19     CZCE  2011-10-24
# 2          RLY0708                 10.0     2007-07-31     SHFE  2006-08-01
# 3            T0412                  5.0     2004-12-15     SHFE  2003-12-30
# 4             null                 10.0     2018-07-13     CZCE  2017-07-17
# 5           DP0503                 10.0     2005-03-14      DCE  2004-03-15
# 6            L0105                  5.0     2001-05-15     SHFE  2000-10-20
# 7           HS1208                300.0     2012-08-17    CFFEX  2012-06-18
# 8         TRXJ0807                  5.0     2008-07-15     SHFE  2007-07-17
# 9            X0711                  5.0     2007-11-15     SHFE  2007-04-04
# 10          DP0903                 10.0     2009-03-13      DCE  2008-03-17
# ...

# %%
instruments('RB1704').tick_size()
# Out:
# 1.0

# %%
instruments('RB1704').contract_multiplier
# Out:
# 10.0

# %%
tickprice = instruments('RB1704').tick_size() * instruments('RB1704').contract_multiplier
tickprice
# Out:
# 10.0

# %%
quantity = (0.02 * 100000) / (20 * tickprice)
quantity
# Out:
# 10.0

# %%
prices = get_price('RB1704', start_date='2016-04-18', end_date='2017-04-17')

# %%
import talib

# %%
atrs = talib.ATR(prices['high'].values, prices['low'].values, prices['close'].values, 100)
atrs
# Out:
# array([         nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
# ...

# %%
quantity = (0.02 * 100000) // (atrs[200] * tickprice)
quantity
# Out:
# 2.0
